# %% [markdown]
# # Taller 4 - Statistic analysis - Nestor Martinez
# For this studio we are goint to use Numpy and SciPy to calculate the average, median, mode, variance and standard deviation of a files of data(sales.csv and expenses.csv), also we are goint to graph in different methods like histograms an boxplots.

# %%
import csv
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure
from scipy import stats
from statistics import mode

# %%
#Lectura de los archivos
sales_reader = pd.read_csv("sales.csv", delimiter = ";")
expenses_reader = pd.read_csv("expenses.csv", delimiter = ";")

#Leemos solo los datos
sales = sales_reader["sales"].values
expenses = expenses_reader["expenses"].values 

#leemos solo las fechas
dates = []
dates_reader = list(sales_reader["date"])
for row in dates_reader:
    dates.append(row.split("/"))
for i in dates:
    i.remove("2021")

# %% [markdown]
# # Histograms
# Histograms reveal, through numbers, interpretable trends in your data. They don’t provide a yes or no answer, but are often used as a starting point for discussion and informing an answer to your data.
#
# The purpose of a histogram is to summarize data that you can use to inform a decision or explain a distribution.
#
# ### Choose a correct number of bins
# We need that all the bars of the histogram have the same width. To calculate this we will use the ruler known as Sturges rule.
#
# #### Sturges rule
# To obtain the Sturges rule, it is only necessary to assume that the number of samples in each interval of an ideal histogram is given by the binomial coefficient. Thus, the total number of samples can be obtained by adding the number of each of the intervals.
#
# $${N} = {\sum_{i}^{k-1}\binom{k-1}{i} = 2^{k-1}}$$
#
# Therefore, we can obtain a formula that depends only on the number of values that exist in the data set.
#
# $${K_{sturges}} = \log_2{|n|} + 1$$

# %%
#histogram for sales


#define the range for the histogram
min_valueS = np.amin(sales)
max_valueS = np.amax(sales)
range_salesS = max_value - min_value

#define numbers of bars
bins = round(np.log2(365) + 1)

#Graph the histogram
plt.hist(sales, range = (min_valueS, max_valueS), bins=bins, edgecolor='black')
plt.title("Histogram of sales of the company in 2021")
plt.xlabel("Value ~ $")
plt.ylabel("Freq")
plt.show()

# %%
#histogram for expenses


#define the range for the histogram
min_valueE = np.amin(expenses)
max_valueE = np.amax(expenses)
range_salesE = max_value - min_value

#define numbers of bars
bins = round(np.log2(365) + 1)

#Graph the histogram
plt.hist(expenses, range = (min_valueE, max_valueE), bins=bins, edgecolor='black')
plt.title("Histogram of expenses of the company in 2021")
plt.xlabel("Value - $")
plt.ylabel("Freq")
plt.show()

# %%
#uti = sales - expenses
utilities = sales - expenses

# %%
#histogram for utilities

#define the range for the histogram
min_valueU = np.amin(utilities)
max_valueU = np.amax(utilities)
range_salesU = max_value - min_value

#define numbers of bars
bins = round(np.log2(365) + 1)

#Graph the histogram
plt.hist(utilities, range = (min_valueU, max_valueU), bins=bins, edgecolor='black')
plt.title("Histogram of utilities of the company in 2021")
plt.xlabel("Value")
plt.ylabel("Freq")
plt.show()

# %% [markdown]
# ### Calculating Mean
#
# The mean, often referred to as the average, is a way to measure the center of a dataset.
#
# The average of a set is calculated using a two-step process:
#
# 1. Add all of the observations in your dataset.
# 2. Divide the total sum from step one by the number of points in your dataset.
#
# $$\bar{x} = \frac{x_1 + x_2 … + x_{n}}{n} $$

# %%
#calculate the average of sales, expenses and utilities
average_sales = int(np.average(sales))
average_expenses = int(np.average(expenses))
average_utilities = int(np.average(utilities))

# %%
#Graph the average of sales in 2021
print(f"The average of sales in 2021 of the company was: ${average_sales}")
plt.hist(sales, range = (min_valueS, max_valueS), bins=bins, edgecolor='black')
plt.title("Histogram of sales of the company in 2021")
plt.xlabel("Value")
plt.ylabel("Freq")
plt.axvline(average_sales, color='r', linestyle='solid', linewidth=2, label="Sales average")
plt.legend()
plt.show()
# Out:
# The average of sales in 2021 of the company was: $1019903

# %%
#Graph the average of expenses in 2021
print(f"The average of expenses in 2021 of the company was: ${average_expenses}")
plt.hist(expenses, range = (min_valueE, max_valueE), bins=bins, edgecolor='black')
plt.title("Histogram of expenses of the company in 2021")
plt.xlabel("Value")
plt.ylabel("Freq")
plt.axvline(average_expenses, color='r', linestyle='solid', linewidth=2, label="Expenses average")
plt.legend()
plt.show()
# Out:
# The average of expenses in 2021 of the company was: $443902

# %%
#Graph the utilities of utilities in 2021
print(f"The average of utilities in 2021 of the company was: ${average_utilities}")
plt.hist(utilities, range = (min_valueU, max_valueU), bins=bins, edgecolor='black')
plt.title("Histogram of utilities of the company in 2021")
plt.xlabel("Value")
plt.ylabel("Freq")
plt.axvline(average_utilities, color='r', linestyle='solid', linewidth=2, label="Utilities average")
plt.legend()
plt.show()
# Out:
# The average of utilities in 2021 of the company was: $576000

# %% [markdown]
# ## Median
#
# The formal definition for the median of a dataset is:
#
# _The value that, assuming the dataset is ordered from smallest to largest, falls in the middle. If there are an even number of values in a dataset, you either report both of the middle two values or their average._
#
# There are always two steps to finding the median of a dataset:
#
# 1. Order the values in the dataset from smallest to largest
# 2. Identify the number(s) that fall(s) in the middle

# %%
#calculate the median of the sales, expenses and utilities
median_sales = int(np.median(sales))
median_expenses = int(np.median(expenses))
median_utilities = int(np.median(utilities))

# %%
#Graph the median of sales in 2021
print(f"The average of sales per month in 2021 of the company was: ${average_sales}")
print(f"The median of sales per month in 2021 of the company was: ${median_sales}")
plt.hist(sales, range = (min_valueS, max_valueS), bins=bins, edgecolor='black')
plt.title("Histogram of sales of the company in 2021")
plt.xlabel("Value - $")
plt.ylabel("Freq")
plt.axvline(median_sales, color='orange', linestyle='solid', linewidth=2, label="Sales median")
plt.axvline(average_sales, color='r', linestyle='solid', linewidth=2, label="Sales average")
plt.legend()
plt.show()
# Out:
# The average of sales per month in 2021 of the company was: $1019903
# The median of sales per month in 2021 of the company was: $950400

# %%
#Graph the median of expenses in 2021
print(f"The average of expenses in 2021 of the company was: ${average_expenses}")
print(f"The median of expenses in 2021 of the company was: ${median_expenses}")
plt.hist(expenses, range = (min_valueE, max_valueE), bins=bins, edgecolor='black')
plt.title("Histogram of expenses of the company in 2021")
plt.xlabel("Value - $")
plt.ylabel("Freq")
plt.axvline(median_expenses, color='orange', linestyle='solid', linewidth=2, label="expenses median")
plt.axvline(average_expenses, color='r', linestyle='solid', linewidth=2, label="expenses average")
plt.legend()
plt.show()
# Out:
# The average of expenses in 2021 of the company was: $443902
# The median of expenses in 2021 of the company was: $418314

# %%
#Graph the median of utilities in 2021
print(f"The average of the utilities in 2021 of the company was: ${average_utilities}")
print(f"The median of the utilities in 2021 of the company was: ${median_utilities}")
plt.hist(utilities, range = (min_valueU, max_valueU), bins=bins, edgecolor='black')
plt.title("Utilities of the company in 2021")
plt.xlabel("Value - $")
plt.ylabel("Freq")
plt.axvline(average_utilities, color='r', linestyle='solid', linewidth=4, label="Utilities average")
plt.axvline(median_utilities, color='orange', linestyle='solid', linewidth=2, label="Utilities median")
plt.legend()
plt.show()
# Out:
# The average of the utilities in 2021 of the company was: $576000
# The median of the utilities in 2021 of the company was: $536610

# %% [markdown]
# ## Mode
#
# The formal definition for the mode of a dataset is:
#
# _The most frequently occurring observation in the dataset. A dataset can have multiple modes if there is more than one value with the same maximum frequency._
#
# There is not directly method to find the mode using Numpy, for that reaseon we will use SciPy fot this task.

# %%
#calculate the mode of sales, expenses and utilities
mode_sales = stats.mode(sales)[0]
mode_expenses = stats.mode(expenses)[0]
mode_utilities = mode(utilities)

# %%
#Graph the mode for the sales of the company in 2021
print(f"The median of sales in 2021 of the company was: ${median_sales}")
print(f"The average of sales in 2021 of the company was: ${average_sales}")
print(f"The mode of sales in 2021 of the company was: ${mode_sales}")
plt.hist(sales, range = (min_valueS, max_valueS), bins=bins, edgecolor='black')
plt.title("Sales of the company in 2021")
plt.xlabel("Value - $")
plt.ylabel("Freq")
plt.axvline(median_sales, color='orange', linestyle='solid', linewidth=3, label="Sales median")
plt.axvline(average_sales, color='r', linestyle='solid', linewidth=3, label="Sales average")
plt.axvline(mode_sales, color='magenta', linestyle='solid', linewidth=3, label="Sales mode")
plt.legend()
plt.show()
# Out:
# The median of sales in 2021 of the company was: $950400
# The average of sales in 2021 of the company was: $1019903
# The mode of sales in 2021 of the company was: $[287000.]

# %%
#Graph the mode for the expenses of the company in 2021
print(f"The median of expenses in 2021 of the company was: ${median_expenses}")
print(f"The average of expenses in 2021 of the company was: ${average_expenses}")
print(f"The mode of expenses in 2021 of the company was: ${mode_expenses}")
plt.hist(expenses, range = (min_valueE, max_valueE), bins=bins, edgecolor='black')
plt.title("Expenses of the company in 2021")
plt.xlabel("Value - $")
plt.ylabel("Freq")
plt.axvline(median_expenses, color='orange', linestyle='solid', linewidth=3, label="Sales median")
plt.axvline(average_expenses, color='r', linestyle='solid', linewidth=3, label="Sales average")
plt.axvline(mode_expenses, color='magenta', linestyle='solid', linewidth=3, label="Sales mode")
plt.legend()
plt.show()
# Out:
# The median of expenses in 2021 of the company was: $418314
# The average of expenses in 2021 of the company was: $443902
# The mode of expenses in 2021 of the company was: $[555.]

# %%
#Graph the mode for the utilities of the company in 2021
print(f"The median of utilities in 2021 of the company was: ${median_utilities}")
print(f"The average of utilities in 2021 of the company was: ${average_utilities}")
print(f"The mode of utilities in 2021 of the company was: ${mode_utilities}")
plt.hist(utilities, range = (min_valueU, max_valueU), bins=bins, edgecolor='black')
plt.title("Utilities of the company in 2021")
plt.xlabel("Value - $")
plt.ylabel("Freq")
plt.axvline(median_utilities, color='orange', linestyle='solid', linewidth=3, label="Utilities median")
plt.axvline(average_utilities, color='r', linestyle='solid', linewidth=3, label="Utilities average")
plt.axvline(mode_utilities, color='magenta', linestyle='solid', linewidth=3, label="Utilities mode")
plt.legend()
plt.show()
# Out:
# The median of utilities in 2021 of the company was: $536610
# The average of utilities in 2021 of the company was: $576000
# The mode of utilities in 2021 of the company was: $144806.0

# %% [markdown]
# # Variance
# Variance is a descriptive statistic that describes how spread out the points in a data set are.
#
# The full equation for the variance is as follows:
#
# $$\sigma^2 = \frac{\sum_{i=1}^{N}{(X_i -\mu)^2}}{N}$$

# %%
#calculate the variance of sales, expenses and utilities
variance_sales = int(np.var(sales))
variance_expenses = int(np.var(expenses))
variance_utilities = int(np.var(utilities))

# %%
#Graph the histogram
plt.hist(sales, range = (min_valueU, max_valueS), bins=bins, edgecolor='black', alpha=0.80, label="Sales")
plt.hist(expenses, range = (min_valueU, max_valueS), bins=bins, edgecolor='black', alpha=0.6, label="Expenses")
plt.hist(utilities, range = (min_valueU, max_valueS), bins=bins, color="green", edgecolor='black', alpha=0.4, label="Utilities")
plt.title("Histogram of sales, expenses and utilities of the company in 2021")
plt.xlabel("Value ~ $")
plt.ylabel("Freq")
plt.legend()
plt.show()

print(f"The average of sales is: ${average_sales}, and the variance is: {variance_sales}")
print(f"The average of expenses is: ${average_expenses}, and the variance is: {variance_expenses}")
print(f"The average of utilities is: ${average_utilities}, and the variance is: {variance_utilities}")
print("We observe a very large variance in each measures of central tendency.")
print("The cause of this is because the data is too away from each other and all the data is in order of (10^6).")
# Out:
# The average of sales is: $1019903, and the variance is: 313882310264
# The average of expenses is: $443902, and the variance is: 101386475742
# The average of utilities is: $576000, and the variance is: 408372299217
# We observe a very large variance in each measures of central tendency.
# The cause of this is because the data is too away from each other and all the data is in order of (10^6).

# %% [markdown]
# ## Standard Deviation
#
# Standard deviation is computed by taking the square root of the variance. `sigma` is the symbol commonly used for standard deviation. Conveniently, `sigma` squared is the symbol commonly used for variance:
#
# $$\sigma = \sqrt{\sigma^2} = \sqrt{\frac{\sum_{i=1}^{N}{(X_i -\mu)^2}}{N}}$$

# %%
#we calculate the standard deviatio of sales, expenses and utilities of the company in 2021
std_sales = np.std(sales)
std_expenses = np.std(expenses)
std_utilities = np.std(utilities)
print(f"The standard deviation of all the data of the sales of the company is: {std_sales}")
print(f"The standard deviation of all the data of the expenses of the company is: {std_expenses}")
print(f"The standard deviation of all the data of the utilities of the company is: {std_utilities}")
print("\nWe observe a deviation smaller than the variance, but it's still very large, because the data is in order of the (*10^7)")
# Out:
# The standard deviation of all the data of the sales of the company is: 560252.0060337939
# The standard deviation of all the data of the expenses of the company is: 318412.4302583038
# The standard deviation of all the data of the utilities of the company is: 639040.1389720306
#
# We observe a deviation smaller than the variance, but it's still very large, because the data is in order of the (*10^7)

# %% [markdown]
# ## Boxplots in Matplotlib
#
# The `matplotlib.pyplot` module has a function named `boxplot()`. `boxplot()` takes a dataset as a parameter. This dataset could be something like a list of numbers, or a Pandas DataFrame.
#
# Some of the major takeaways from boxplots are:
#
# - The box of a boxplot visualizes the median, first quartile, and third quartile of a dataset.
# - The length of the box in a boxplot visualizes the interquartile range.
# - The whiskers extend from the box 1.5 times the size of the interquartile range.
# - Outliers are points that fall outside of the whiskers. They’re represented by dots.
# - Boxplots are especially useful for comparing the spread of multiple datasets.

# %%
plt.boxplot([sales, expenses, utilities])
plt.title("Boxplots of sales, expenses and utilities of the company in 2021\n")
plt.show()
